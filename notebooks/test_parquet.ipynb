# %%
import sys
from pyspark.sql import SparkSession
sys.path.insert(0, '/src/pipeline')
sys.path.insert(0, '/src/similarity')

# from load_data import load_arxiv_data
# from spark_minhash import SparkMinHash
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import sys
# ----> 2 from pyspark.sql import SparkSession
#       3 sys.path.insert(0, '/src/pipeline')
#       4 sys.path.insert(0, '/src/similarity')
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
spark = SparkSession.uilder \
            .appName("Test_Parquet") \
            .getOrCreate()

# %%
output_path="/data/minhash_signatures.parquet"
df_loaded = spark.read.parquet(output_path)
verify_count = df_loaded.count()
print(f" Verified {verify_count:,} records in Parquet")

# %%
df_loaded.show(5, truncate=50)
